# %%
import os
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import pandas as pd
import requests

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
url = 'https://finance.yahoo.com/quote/TSLA/history?p=TSLA'
driver.get(url)

data =[]
for i in range(1,31):
    date = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[1]/span').text
    open = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[2]/span').text
    high = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[3]/span').text
    low = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[4]/span').text
    close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[5]/span').text
    adj_close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[6]/span').text
    volume = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[7]/span').text
    
    data.append({'date' : date,
                    'open' : open,
                    'high' :high,
                    'low': low,
                    'close':close,
                    'adj_close': adj_close,
                    'volume':volume})
    
cs =  pd.DataFrame(data)


cs
# Out:
#             date    open    high     low   close adj_close       volume
# 0   Nov 11, 2022  186.00  196.52  182.59  195.97    195.97  114,229,200
# 1   Nov 10, 2022  189.90  191.00  180.03  190.72    190.72  132,703,000
# 2   Nov 09, 2022  190.78  195.89  177.12  177.59    177.59  127,062,700
# 3   Nov 08, 2022  194.02  195.20  186.75  191.30    191.30  128,803,400
# 4   Nov 07, 2022  208.65  208.90  196.66  197.08    197.08   93,916,500
# 5   Nov 04, 2022  222.60  223.80  203.08  207.47    207.47   98,453,100
# 6   Nov 03, 2022  211.36  221.20  210.14  215.31    215.31   56,538,800
# 7   Nov 02, 2022  226.04  227.87  214.82  214.98    214.98   63,070,300
# 8   Nov 01, 2022  234.05  237.40  227.28  227.82    227.82   62,688,800
# 9   Oct 31, 2022  226.19  229.85  221.94  227.54    227.54   61,554,300
# 10  Oct 28, 2022  225.40  228.86  216.35  228.52    228.52   69,152,400
# 11  Oct 27, 2022  229.77  233.81  222.85  225.09    225.09   61,638,800
# ...

# %% [markdown]
# Input the #past data you want to get

# %%
from datetime import date
year = 2022
month = 11
day = 1


stock_name = str('TSLA')
d1 = date(year,month,day)
now = date.today()
result = abs(now - d1).days
result
# Out:
# 16

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
url = 'https://finance.yahoo.com/quote/'+ stock_name +'/history?p='+ stock_name 
driver.get(url)

data =[]
for i in range(1,result+1):
    date = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[1]/span').text
    open = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[2]/span').text
    high = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[3]/span').text
    low = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[4]/span').text
    close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[5]/span').text
    adj_close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[6]/span').text
    volume = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[7]/span').text
    
    data.append({'date' : date,
    'stock_name' : stock_name,
                    'open' : open,
                    'high' :high,
                    'low': low,
                    'close':close,
                    'adj_close': adj_close,
                    'volume':volume})
    
cs =  pd.DataFrame(data)

cs
# Out:
#             date stock_name    open    high     low   close adj_close  \
# 0   Nov 11, 2022       TSLA  186.00  196.52  182.59  195.97    195.97
# 1   Nov 10, 2022       TSLA  189.90  191.00  180.03  190.72    190.72
# 2   Nov 09, 2022       TSLA  190.78  195.89  177.12  177.59    177.59
# 3   Nov 08, 2022       TSLA  194.02  195.20  186.75  191.30    191.30
# 4   Nov 07, 2022       TSLA  208.65  208.90  196.66  197.08    197.08
# 5   Nov 04, 2022       TSLA  222.60  223.80  203.08  207.47    207.47
# 6   Nov 03, 2022       TSLA  211.36  221.20  210.14  215.31    215.31
# 7   Nov 02, 2022       TSLA  226.04  227.87  214.82  214.98    214.98
# 8   Nov 01, 2022       TSLA  234.05  237.40  227.28  227.82    227.82
# 9   Oct 31, 2022       TSLA  226.19  229.85  221.94  227.54    227.54
# 10  Oct 28, 2022       TSLA  225.40  228.86  216.35  228.52    228.52
#
#          volume
# 0   114,229,200
# 1   132,703,000
# 2   127,062,700
# 3   128,803,400
# 4    93,916,500
# 5    98,453,100
# ...

# %%
from datetime import date
start_year = 2022
start_month = 11
start_day = 1


end_year = 2022
end_month = 11
end_day = 5


stock_name = str('TSLA')
start_date = date(start_year, start_month, start_day)
end_date = date(end_year, end_month, end_day)
now = date.today()

start_day_indx = abs(now - start_date).days
end_day_indx = abs(now - end_date).days

print(int(start_day_indx))
print(int(end_day_indx))
# Out:
# 12
# 8

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
url = 'https://finance.yahoo.com/quote/'+ stock_name +'/history?p='+ stock_name 
driver.get(url)

date_in_sys = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr[1]/td[1]/span').text

date_in_sys_splt = date_in_sys.split()
print(date_in_sys)
print(date_in_sys_splt)
# Out:
# /var/folders/6v/gvmn70fn0r7785qthfhm7cnr0000gn/T/ipykernel_19202/1229418866.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="chromedriver.exe")
# Nov 11, 2022
# ['Nov', '11,', '2022']

# %%
import datetime
timestamps = [datetime.datetime(curr_year_in_web, curr_month_in_web, curr_day_in_web, 0, 0)]
[d.strftime('%m-%d-%Y') for d in timestamps]
# Out:
# ['11-21-2016', '11-22-2016', '11-23-2016']

# %%
curr_month_in_web = 0
curr_month_in_web = (strptime(date_in_sys[0:3],'%b').tm_mon)
curr_day_in_web = (int(date_in_sys[4:6]))
curr_year_in_web = (int(date_in_sys[8:12]))

# print(curr_month_in_web)
# print(curr_day_in_web)
# print(curr_year_in_web)

# print([curr_year_in_web, curr_month_in_web, curr_day_in_web])

# curr_date_in_web = date(curr_year_in_web, curr_month_in_web, curr_day_in_web)
# print(curr_day_in_web)

import datetime
timestamps = [datetime.datetime(curr_year_in_web, curr_month_in_web, curr_day_in_web, 0, 0)]
a = [d.strftime('%m-%d-%Y') for d in timestamps]
a = a[0]
a
print(type(a))

# from datetime import datetime

date_time_obj = datetime.datetime.strptime(a, '%m/%d/%y')
date_time_obj
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [99], line 24
#      20 print(type(a))
#      22 # from datetime import datetime
# ---> 24 date_time_obj = datetime.datetime.strptime(a, '%m/%d/%y')
#      25 date_time_obj
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/_strptime.py?line=564'>565</a> def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/_strptime.py?line=565'>566</a>     """Return a class cls instance based on the input string and the
# ...

# %%
now = date.today()
print(now)

diff_bet_web_and_now = abs(now - a).days
print(int(diff_bet_web_and_now))
# Out:
# 2022-11-13
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [97], line 4
#       1 now = date.today()
#       2 print(now)
# ----> 4 diff_bet_web_and_now = abs(now - a).days
#       5 print(int(diff_bet_web_and_now))
#
# TypeError: unsupported operand type(s) for -: 'datetime.date' and 'str'

# %%
from time import strptime

curr_month_in_web = 0
curr_month_in_web += int(strptime(date_in_sys[0],'%b').tm_mon)
print(curr_month_in_web)

curr_day_in_web = 0
curr_day_in_web += int(date_in_sys[1][0:2])
print(curr_day_in_web)

curr_year_in_web = 0
curr_year_in_web += int(date_in_sys[2])
print(curr_year_in_web)

curr_date_in_web = date(curr_year_in_web, curr_month_in_web, curr_day_in_web)
print(curr_day_in_web)

now = date.today()

diff_bet_web_and_now = abs(now - curr_date_in_web).days
print(int(diff_bet_web_and_now))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 4
#       1 from time import strptime
#       3 curr_month_in_web = 0
# ----> 4 curr_month_in_web += int(strptime(date_in_sys[0],'%b').tm_mon)
#       5 print(curr_month_in_web)
#       7 curr_day_in_web = 0
#
# NameError: name 'date_in_sys' is not defined

# %%
from datetime import date
year = 2022
month = 11
day = 1


stock_name = str('TSLA')
d1 = date(year,month,day)
now = date.today()
result = abs(now - d1).days
result
# Out:
# 16

# %%
from datetime import date
start_year = 2022
start_month = 11
start_day = 1


end_year = 2022
end_month = 11
end_day = 5


stock_name = str('TSLA')
start_date = date(start_year, start_month, start_day)
end_date = date(end_year, end_month, end_day)
now = date.today()

start_day_indx = abs(now - start_date).days
end_day_indx = abs(now - end_date).days

print(int(start_day_indx))
print(int(end_day_indx))
# Out:
# 16
# 12

# %%
driver = webdriver.Chrome(executable_path="chromedriver.exe")
url = 'https://finance.yahoo.com/quote/'+ stock_name +'/history?p='+ stock_name 
driver.get(url)

data =[]
for i in range(end_day_indx,start_day_indx):
    date = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[1]/span').text
    open = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[2]/span').text
    high = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[3]/span').text
    low = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[4]/span').text
    close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[5]/span').text
    adj_close = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[6]/span').text
    volume = driver.find_element("xpath", '//*[@id="Col1-1-HistoricalDataTable-Proxy"]/section/div[2]/table/tbody/tr['+str(i)+']/td[7]/span').text
    
    data.append({'date' : date,
    'stock_name' : stock_name,
                    'open' : open,
                    'high' :high,
                    'low': low,
                    'close':close,
                    'adj_close': adj_close,
                    'volume':volume})
    
cs =  pd.DataFrame(data)

cs
# Out:
# /var/folders/6v/gvmn70fn0r7785qthfhm7cnr0000gn/T/ipykernel_17765/1056133838.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="chromedriver.exe")
#            date stock_name    open    high     low   close adj_close  \
# 0  Nov 02, 2022       TSLA  226.04  227.87  214.82  214.98    214.98
# 1  Nov 01, 2022       TSLA  234.05  237.40  227.28  227.82    227.82
# 2  Oct 31, 2022       TSLA  226.19  229.85  221.94  227.54    227.54
# 3  Oct 28, 2022       TSLA  225.40  228.86  216.35  228.52    228.52
#
#        volume
# 0  63,070,300
# 1  62,688,800
# 2  61,554,300
# 3  69,152,400
